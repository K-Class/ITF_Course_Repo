# %%
import matplotlib.pyplot as p

# %% [markdown]
# ## Programlama Dilleri Tercih Oranları

# %%
s = [40,30,10,10,10]
i = ["Python", "Java", "C++","C","Javascript"]
p.pie(s, labels = i)
p.show()

# %% [markdown]
# ## Deniz Suyundan Elde Edilen Tuzun Bileşenleri

# %%
s = [54,8,1,31,1,4,1]
i = ["Klor", "Sülfat", "Diğer","Sodyum","Potasyum","Magnezyum","Kalsiyum"]
p.pie(s, labels = i)
p.show()

# %%
s = [54,8,1,31,1,4,1]
i = ["Klor", "Sülfat", "Diğer","Sodyum","Potasyum","Magnezyum","Kalsiyum"]
p. (s, labels = i)
p.show()
